# %%
from CovidTemporalPrediction import CovidTemporalPredictor

# %%
test_state_name = "Texas"
temporal_predictor = CovidTemporalPredictor(state_name=test_state_name)

# %%
_ = temporal_predictor.plot_input_data()

# %%
temporal_predictor.setup_model(train_fraction=0.9)
# Out:
# Texas model setup
# <style type="text/css">
# #T_26a15_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_26a15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26a15_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_26a15_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26a15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26a15_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_26a15_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_26a15_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26a15_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_26a15_row1_col1" class="data row1 col1" >Texas</td>
#     </tr>
#     <tr>
#       <th id="T_26a15_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
temporal_predictor.train_model(error_metric="MSE")
# Out:
# Texas: Training on different models
# <style type="text/css">
# #T_9133a th {
#   text-align: left;
# }
# ...

# %%
ax = temporal_predictor.plot_model_fit()
# Out:
# <style type="text/css">
# </style>
# <table id="T_41ebb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41ebb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_41ebb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_41ebb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_41ebb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_41ebb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_41ebb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_41ebb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41ebb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41ebb_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_41ebb_row0_col1" class="data row0 col1" >3245.8091</td>
# ...

# %%
ax = temporal_predictor.predict_and_plot_future()
